# %%
# %%bash
# git init
# git remote add origin https://github.com/BillyPaul123/Elephant_Mortality_Rate.git
# Out:
# Reinitialized existing Git repository in /home/user/Capstone Project on Elephant Mortality Rate/.git
# /
# error: remote origin already exists.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'git init\ngit remote add origin https://github.com/BillyPaul123/Elephant_Mortality_Rate.git\n')
#
# File /ext/venvs/cocalc/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /ext/venvs/cocalc/lib/python3.12/site-packages/IPython/core/magics/script.py:160, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     158 else:
#     159     line = script
# --> 160 return self.shebang(line, cell)
#
# File /ext/venvs/cocalc/lib/python3.12/site-packages/IPython/core/magics/script.py:343, in ScriptMagics.shebang(self, line, cell)
#     338 if args.raise_error and p.returncode != 0:
#     339     # If we get here and p.returncode is still None, we must have
#     340     # killed it but not yet seen its return code. We don't wait for it,
#     341     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     342     rc = p.returncode or -9
# --> 343     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'git init\ngit remote add origin https://github.com/BillyPaul123/Elephant_Mortality_Rate.git\n'' returned non-zero exit status 3.

# %%
# %%bash
# git add .
# git commit -m "Initial commit - add project files"
# git branch -M main
# git push -u origin main
# Out:
# [main (root-commit) 8649cfd] Initial commit - add project files
#  18 files changed, 1436 insertions(+
# )
#  create mode 100644 .Elephant Mortality Rate.ipynb.sage-jupyter2
#  create mode 100644 .git.ipynb.sa
# ge-jupyter2
#  create mode 100644 Elephant Mortality Rate.ipynb
#  create mode 100644 Elephant_mortality
# _rate/analysis/README.md
#  create mode 100644 Elephant_mortality_rate/data_processed/README.md
#  creat
# e mode 100644 Elephant_mortality_rate/data_raw/README.md
#  create mode 100644 Elephant_mortality_rate
# /docs/README.md
#  create mode 100644 Elephant_mortality_rate/outputs/README.md
#  create mode 100644 El
# ephant_mortality_rate/scripts/README.md
#  create mode 100644 Laikipia_Samburu_Landscapezip.zip
#  creat
# e mode 100644 Laikipia_Samburu_Landscapezip/Laikipia_Samburu_Landscape.cpg
#  create mode 100644 Laiki
# pia_Samburu_Landscapezip/Laikipia_Samburu_Landscape.dbf
#  create mode 100644 Laikipia_Samburu_Landsca
# pezip/Laikipia_Samburu_Landscape.prj
#  create mode 100644 Laikipia_Samburu_Landscapezip/Laikipia_Samb
# uru_Landscape.qmd
#  create mode 100644 Laikipia_Samburu_Landscapezip/Laikipia_Samburu_Landscape.shp
# create mode 100644 Laikipia_Samburu_Landscapezip/Laikipia_Samburu_Landscape.shx
#  create mode 100644
# MIKE data_Laikipia Samburu_harmonisation_230216 (1).xlsx
#  create mode 100644 git.ipynb
# fatal: could not read Username for 'https://github.com': No such device or address
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', 'git add .\ngit commit -m "Initial commit - add project files"\ngit branch -M main\ngit push -u origin main\n')
#
# File /ext/venvs/cocalc/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2565, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2563 with self.builtin_trap:
#    2564     args = (magic_arg_s, cell)
# -> 2565     result = fn(*args, **kwargs)
#    2567 # The code below prevents the output from being displayed
#    2568 # when using magics with decorator @output_can_be_silenced
#    2569 # when the last Python token in the expression is a ';'.
#    2570 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /ext/venvs/cocalc/lib/python3.12/site-packages/IPython/core/magics/script.py:160, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     158 else:
#     159     line = script
# --> 160 return self.shebang(line, cell)
#
# File /ext/venvs/cocalc/lib/python3.12/site-packages/IPython/core/magics/script.py:343, in ScriptMagics.shebang(self, line, cell)
#     338 if args.raise_error and p.returncode != 0:
#     339     # If we get here and p.returncode is still None, we must have
#     340     # killed it but not yet seen its return code. We don't wait for it,
#     341     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     342     rc = p.returncode or -9
# --> 343     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'git add .\ngit commit -m "Initial commit - add project files"\ngit branch -M main\ngit push -u origin main\n'' returned non-zero exit status 128.
